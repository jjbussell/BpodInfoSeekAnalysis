# %%
## package setup and import
import numpy as np
import datajoint as dj
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import datetime
from scipy.io import loadmat

# %%
# path = '/Users/jbuss/Code/datapipeline'
# files = os.listdir(path)
folder = os.getcwd()
print(folder)
# Out:
# C:\Users\jbuss\Code\Bpod\Analysis

# %%
## datajoint setup/import for database management
dj.__version__

dj.config['database.host'] = '127.0.0.1'
dj.config['database.port'] = 3306
dj.config['database.user'] = 'root'
dj.config['database.password'] = 'simple'
dj.config['fetch_format'] = 'array'
dj.config['enable_python_native_blobs'] = True 


connection = dj.conn()
connection
# Out:
# Connecting root@127.0.0.1:3306
# DataJoint connection (connected) root@127.0.0.1:3306

# %%
dj.config['stores'] = {
    'raw_data':{
        'protocol':'file',
        'location': os.path.join(folder,'raw_data')
    }
}

dj.config.save_global()

# %%
# Change this so it's IN the tables and ignores dublicates

datafiles = []
filenames = []
for file in glob.glob(r"C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB*\TestInfoseek\Session Data\*.mat"):
        filenames.append(file[file.find('JB',45):])
        datafiles.append(file)

# %%
# schema.drop(True)
schema = dj.schema('behavioral')
schema.drop(True)
schema = dj.schema('behavioral')

# %%
@schema
class Mice(dj.Manual): ## Manual entry table for mouse identification/attribute labelling
    definition = """
    mouse_id : varchar(100) 
    ---
    sex = 'U': enum('F','M','U')
    
    geno = 'C57BL6' : varchar(50)
    imaging = null : int
    """

#     DOB = null : date  # YYYY-MM-DD

# %%
# format for entry of new mouse with new attributes, load later on will create new mouse if not previously entered but will be missing experimental params
mice = Mice()

mice.insert([{'mouse_id' : 'JB366', 'sex' : 'M'},{'mouse_id' : 'JB367','sex' :'F'},{'mouse_id' : 'JB368', 'sex' : 'M'},{'mouse_id' : 'JB369', 'sex' : 'M'}],skip_duplicates=True)
mice

# dj.ERD(schema)
# Out:
# *mouse_id    sex     geno       imaging
# +----------+ +-----+ +--------+ +---------+
# JB366        M       C57BL6     None
# JB367        F       C57BL6     None
# JB368        M       C57BL6     None
# JB369        M       C57BL6     None
#  (Total: 4)

# %%
# any dates where sessions are logged and any associated mice are compiled

@schema
class ExpDates(dj.Manual):
    definition = """
    mouse_id : varchar(50)
    date : varchar(50)
    """
    
    
    def newDate(self,datafile):
        data = loadmat(datafile)
        filename = datafile[datafile.find('JB',45):]
        mouse_id = filename.split('_')[0]
        date = data['SessionData']['Info'][0][0][0][0][1][0]
        ExpDates.insert1({'mouse_id':mouse_id,'date':date},skip_duplicates=True)

# dj.ERD(schema)

# %%
# datafiles associated with specific testing dates and times with what associated file name

@schema
class TestingSession(dj.Manual): ## Manual entry table for each recording session -- want to automate (imported data table - import table characteristics from recording files)
    definition = """
    -> Mice
    -> ExpDates
    time : varchar(50)
    datafile : varchar(200)
    ---
    comments = null : varchar(1000)
    """



    def insertSession(self,datafile):
        data = loadmat(datafile)
        filename = datafile[datafile.find('JB',45):]
        mouse_id = filename.split('_')[0]
        date = data['SessionData']['Info'][0][0][0][0][1][0]
        time = data['SessionData']['Info'][0][0][0][0][2][0]
        settings = pd.DataFrame(data['SessionData']['TrialSettings'][0][0][0])
        init_settings = pd.DataFrame(settings.iloc[0])
        final_settings = pd.DataFrame(settings.iloc[len(settings)-1])
        TestingSession.insert1({'mouse_id':mouse_id,'date':date,'time':time,'datafile':datafile},skip_duplicates=True)

# %%
# datafiles associated with specific testing dates and times with what associated file name

@schema
class TestingSession(dj.Manual): ## Manual entry table for each recording session -- want to automate (imported data table - import table characteristics from recording files)
    definition = """
    -> Mice
    -> ExpDates
    time : varchar(50)
    datafile : varchar(200)
    ---
    comments = null : varchar(1000)
    """



    def insertSession(self,datafile):
        data = loadmat(datafile)
        filename = datafile[datafile.find('JB',45):]
        mouse_id = filename.split('_')[0]
        date = data['SessionData']['Info'][0][0][0][0][1][0]
        time = data['SessionData']['Info'][0][0][0][0][2][0]
        settings = pd.DataFrame(data['SessionData']['TrialSettings'][0][0][0])
        init_settings = pd.DataFrame(settings.iloc[0])
        final_settings = pd.DataFrame(settings.iloc[len(settings)-1])
        TestingSession.insert1({'mouse_id':mouse_id,'date':date,'time':time,'datafile':datafile},skip_duplicates=True)

# %%
# list raw data and trial settings 

@schema
class SessionData(dj.Imported):
    definition = """
    -> Mice
    -> TestingSession
    ---
    raw_data : longblob
    init_settings : longblob
    final_settings : longblob
    """
    
    def make(self,key):
        data = loadmat((TestingSession & key).fetch1()['datafile'])
        settings = pd.DataFrame(data['SessionData']['TrialSettings'][0][0][0])
        key['raw_data'] = pd.DataFrame(data['SessionData'][0])
        key['init_settings'] = pd.DataFrame(settings.iloc[0])
        key['final_settings'] = pd.DataFrame(settings.iloc[len(settings)-1])
        self.insert1(key)

# %%
# enter data into manual entry tables

def newEntry(datafile):
    filename = datafile[datafile.find('JB',45):]
    mouse_id = filename.split('_')[0]
    Mice.insert1({'mouse_id': mouse_id},skip_duplicates = True)
    ExpDates().newDate(datafile)
    TestingSession().insertSession(datafile)



    
for i in datafiles: 
    try:
        newEntry(i)
        print(i + ': loaded')
    except ValueError:
        print(i + ': incomplete file')



# for file in os.listdir(r"C:\Users\ashwi\Dropbox\BpodInfoseek\Data\JB366\CenterTraining\Session Data"):
#     if file.startswith("JB"):
#         print(os.listdir(r"C:\Users\ashwi\Dropbox\BpodInfoseek\Data\JB366\CenterTraining\Session Data"))
#         newEntry(os.path.join(r"C:\Users\ashwi\Dropbox\BpodInfoseek\Data\JB366\CenterTraining\Session Data",file),str())
# dj.ERD(schema)
# Out:
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200831_140956.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200831_142200.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200831_142331.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200831_143516.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200901_122435.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200901_124714.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200901_130932.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200902_120322.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200902_121653.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200903_124237.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200903_124906.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200903_125411.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200903_130203.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200904_134451.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200904_135223.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200904_141120.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200908_135040.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200909_112322.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200909_114109.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200909_114548.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200910_111705.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200910_113423.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200911_100136.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200911_101825.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200911_102332.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200911_103007.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB366\TestInfoseek\Session Data\JB366_TestInfoseek_20200911_104810.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200831_144947.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200831_145824.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200831_151401.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200901_135559.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200901_141835.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200902_150420.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200902_152240.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200903_133353.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200903_133513.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200903_140039.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200904_143134.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200904_144257.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200904_144451.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200904_145455.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200908_141402.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200908_141536.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200908_141712.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200908_150101.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200908_151320.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_121254.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_122609.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_123831.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_124636.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_125647.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200909_150106.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200910_130720.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200910_130731.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200910_132622.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200910_134549.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200911_105505.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200911_111306.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200911_112713.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB367\TestInfoseek\Session Data\JB367_TestInfoseek_20200911_114827.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200831_161425.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200831_162553.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200831_163346.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200901_145833.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200901_152418.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200902_161046.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200902_161524.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200902_162655.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200902_164357.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_142657.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_143344.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_144048.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_144515.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_145019.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_145726.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200903_145807.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_151014.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_151331.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_151752.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_152329.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_152849.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200904_154422.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200909_140757.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200909_141324.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200909_142554.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200909_143534.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_141130.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_142145.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_142650.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_142944.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_143004.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_143150.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_143726.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200910_144342.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_130532.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_131011.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_131346.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_131546.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_131955.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_132018.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_132433.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_132914.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_133127.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_133642.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB368\TestInfoseek\Session Data\JB368_TestInfoseek_20200911_134039.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200831_153017.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200831_153734.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200831_155246.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200831_160043.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200901_154407.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200901_161928.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200901_163156.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_170814.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_171921.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_172122.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_172203.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_174030.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_174416.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_174808.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200902_174836.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200903_151211.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200903_152910.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200903_153944.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200903_154034.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200903_154927.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200904_155525.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200904_160503.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200904_160727.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200904_161438.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_151151.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_152122.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_152832.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_153308.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_154340.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_154733.mat: incomplete file
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_154802.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200909_155702.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_162425.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_163429.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_164729.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_170213.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_171355.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200910_171608.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200911_142729.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200911_143552.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200911_144351.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200911_144732.mat: loaded
# C:\Users\jbuss\Dropbox\BpodInfoseek\Data\JB369\TestInfoseek\Session Data\JB369_TestInfoseek_20200911_145335.mat: loaded

# %%
# create table that compiles water and number of trials per experimental session

@schema
class SessionWater(dj.Computed):
    definition = """
    -> TestingSession
    ---
    water_vol_ul : int
    drop_size : int
    num_trials : int
    """
    
    def make(self,key):
        dropVol = 4 # mL
        data = (SessionData & key).fetch1()['raw_data']
        trialEvents = data['RawEvents'][0][0][0][0][0]
        numDrops = []
        numTrials = len(trialEvents)
        for i in np.arange(len(trialEvents)):
            try:
                dropCount = len(trialEvents[i][0][0][1]['GlobalTimer3_End'][0][0][0])
            except ValueError:
                try:
                    dropCount = len(trialEvents[i][0][0][1]['GlobalTimer4_End'][0][0][0])
                except ValueError:
                    dropCount = 0

            numDrops.append(dropCount)

        totalDrops = sum(numDrops)
        
        key['water_vol_ul'] = totalDrops*dropVol
        key['drop_size'] = dropVol
        key['num_trials'] = numTrials
        self.insert1(key)
        
# dj.ERD(schema)

# %%
# table with day summary of total water given through experimental trials for individual mice each day

@schema
class DaySummaries(dj.Imported):
    definition = """
    -> ExpDates
    ---
    total_water_ul : int
    """
    
    def make(self,key):
        mouseID = (ExpDates & key).fetch()['mouse_id']
        dates = (ExpDates & key).fetch()['date']
        for i in mouseID:
            for j in dates:
                dayWater = sum((SessionWater & 'mouse_id = ' + str('"' + i + '"') & 'date = ' + str('"' + j + '"')).fetch()['water_vol_ul'])
                key['total_water_ul'] = dayWater
        self.insert1(key)    

# dj.ERD(schema)

# %%
@schema
class OutcomesPlot(dj.Computed):
    definition = """
    -> SessionData
    ---
    num_trials : int
    outcomes : longblob
    """
    
    def make(self,key):
        data = loadmat((TestingSession & key).fetch1()['datafile'])
        outcomes = pd.DataFrame(data['SessionData']['Outcomes'][0][0][0])
        numTrials = len(outcomes)
        key['num_trials'] = numTrials
        key['outcomes'] = outcomes
        self.insert1(key)

# dj.ERD(schema)

# %%
@schema
class TrialStates(dj.Imported):
    definition = """
    -> TestingSession
    ---
    start_trial : blob
    wait_for_center : blob
    center_delay : blob
    center_odor : blob
    center_post_odor_delay : blob
    go_cue : blob
    response : blob
    wait_for_odor_l : blob
    wait_for_odor_r : blob
    odor_left : blob
    odor_right : blob
    reward_delay_left : blob
    reward_delay_right : blob
    left_port_check : blob
    left_not_present : blob
    right_not_present : blob
    left_big_reward : blob
    left_small_reward : blob
    right_big_reward : blob
    right_small_reward : blob
    outcome_delivery : blob
    incorrect_left : blob
    incorrect_right : blob
    no_choice : blob
    incorrect : blob
    timeout_odor : blob
    timeout_reward_delay : blob
    timeout_outcome : blob
    intertrial_interval : blob
    """    
#     right_port_check : blob

    
    def make(self,key):
        trials = loadmat((TestingSession & key).fetch1()['datafile'])['SessionData']['RawEvents'][0][0][0][0][0][0]
        for i in np.arange(len(trials)):
                trialstate = trials[i][0][0][0][0]
                start_trial[i] = (trialstate['StartTrial'])
                wait_for_center[i] = (trialstate['WaitForCenter'])
                center_delay[i] = (trialstate['CenterDelay'])
                center_odor[i] = (trialstate['CenterOdor'])
                center_post_odor_delay[i] = (trialstate['CenterPostOdorDelay'])
                go_cue[i] = (trialstate['GoCue'])
                response[i] = (trialstate['Response'])
                wait_for_odor_l[i] = (trialstate['WaitForOdorLeft'])
                wait_for_odor_r[i] = (trialstate['WaitForOdorRight'])
                odor_left[i] = (trialstate['OdorLeft'])
                odor_right[i] = (trialstate['OdorRight'])
                reward_delay_left[i] = (trialstate['RewardDelayLeft'])
                reward_delay_right[i] = (trialstate['RewardDelayRight'])
                left_port_check[i] = (trialstate['LeftPortCheck'])
        #             right_port_check[i] = pd.DataFrame(trialstate['RightPortCheck'])
                left_not_present[i] = (trialstate['LeftNotPresent'])
                right_not_present[i] = (trialstate['RightNotPresent'])
                left_big_reward[i] = (trialstate['LeftBigReward'])
                left_small_reward[i] = (trialstate['LeftSmallReward'])
                right_big_reward[i] = (trialstate['RightBigReward'])
                right_small_reward[i] = (trialstate['RightSmallReward'])
                outcome_delivery[i] = (trialstate['OutcomeDelivery'])
                incorrect_left[i] = (trialstate['IncorrectLeft'])
                incorrect_right[i] = (trialstate['IncorrectRight'])
                no_choice[i] = (trialstate['NoChoice'])
                incorrect[i] = (trialstate['Incorrect'])
                timeout_odor[i] = (trialstate['TimeoutOdor'])
                timeout_reward_delay[i] = (trialstate['TimeoutRewardDelay'])
                timeout_outcome[i]  = (trialstate['TimeoutOutcome'])
                intertrial_interval[i] = (trialstate['InterTrialInterval'])
        
            
            
            
        key['start_trial'] = start_trial
        key['wait_for_center'] = wait_for_center
        key['center_delay'] = center_delay
        key['center_odor'] = center_odor
        key['center_post_odor_delay'] = center_post_odor_delay
        key['go_cue'] = go_cue
        key['response'] = response
        key['wait_for_odor_l'] = wait_for_odor_l
        key['wait_for_odor_r'] = wait_for_odor_r
        key['odor_left'] = odor_left
        key['odor_right'] = odor_right
        key['reward_delay_left'] = reward_delay_left
        key['reward_delay_right'] = reward_delay_right
        key['left_port_check'] = left_port_check
        key['left_not_present'] = left_not_present
#         key['right_port_check'] = right_port_check
        key['right_not_present'] = right_not_present
        key['left_big_reward'] = left_big_reward
        key['left_small_reward'] = left_small_reward
        key['right_big_reward'] = right_big_reward
        key['right_small_reward'] = right_small_reward
        key['outcome_delivery'] = outcome_delivery
        key['incorrect_left'] = incorrect_left
        key['incorrect_right'] = incorrect_right
        key['no_choice'] = no_choice
        key['incorrect'] = incorrect
        key['timeout_odor'] = timeout_odor
        key['timeout_reward_delay'] = timeout_reward_delay
        key['timeout_outcome'] = timeout_outcome
        key['intertrial_interval'] = intertrial_interval
        
        self.insert1(key)
        
# dj.ERD(schema)

# %%
#populate initial imported/computed tables

SessionData.populate()
SessionWater.populate()
DaySummaries.populate()
OutcomesPlot.populate()
# TrialStates.populate()

# dj.ERD(schema)

# %%
SessionData()
# Out:
# *mouse_id    *date          *time        *datafile      raw_data   init_setti final_sett
# +----------+ +------------+ +----------+ +------------+ +--------+ +--------+ +--------+
# JB366        01-Sep-2020    12:31:51     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        01-Sep-2020    12:47:45     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        01-Sep-2020    13:11:05     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        02-Sep-2020    12:08:04     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        02-Sep-2020    12:17:26     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        03-Sep-2020    12:46:38     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        03-Sep-2020    12:50:31     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        03-Sep-2020    12:55:01     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        03-Sep-2020    13:03:56     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        04-Sep-2020    13:46:03     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        04-Sep-2020    13:53:57     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
# JB366        04-Sep-2020    14:13:09     C:\Users\jbuss =BLOB=     =BLOB=     =BLOB=
#    ...
#  (Total: 134)

# %%
SessionWater()
# Out:
# *mouse_id    *date          *time        *datafile      water_vol_ul   drop_size     num_trials
# +----------+ +------------+ +----------+ +------------+ +------------+ +-----------+ +------------+
# JB366        01-Sep-2020    12:31:51     C:\Users\jbuss 100            4             25
# JB366        01-Sep-2020    12:47:45     C:\Users\jbuss 204            4             51
# JB366        01-Sep-2020    13:11:05     C:\Users\jbuss 28             4             8
# JB366        02-Sep-2020    12:08:04     C:\Users\jbuss 140            4             36
# JB366        02-Sep-2020    12:17:26     C:\Users\jbuss 200            4             50
# JB366        03-Sep-2020    12:46:38     C:\Users\jbuss 68             4             17
# JB366        03-Sep-2020    12:50:31     C:\Users\jbuss 100            4             26
# JB366        03-Sep-2020    12:55:01     C:\Users\jbuss 116            4             29
# JB366        03-Sep-2020    13:03:56     C:\Users\jbuss 100            4             25
# JB366        04-Sep-2020    13:46:03     C:\Users\jbuss 84             4             21
# JB366        04-Sep-2020    13:53:57     C:\Users\jbuss 60             4             15
# JB366        04-Sep-2020    14:13:09     C:\Users\jbuss 28             4             14
#    ...
#  (Total: 134)

# %%
DaySummaries()
# Out:
# *mouse_id    *date          total_water_ul
# +----------+ +------------+ +------------+
# JB366        01-Sep-2020    332
# JB366        02-Sep-2020    340
# JB366        03-Sep-2020    384
# JB366        04-Sep-2020    172
# JB366        08-Sep-2020    0
# JB366        09-Sep-2020    284
# JB366        10-Sep-2020    92
# JB366        11-Sep-2020    684
# JB366        31-Aug-2020    160
# JB367        01-Sep-2020    64
# JB367        02-Sep-2020    168
# JB367        03-Sep-2020    200
#    ...
#  (Total: 34)

# %%
DaySummaries & 'date = "10-Sep-2020"'
# Out:
# *mouse_id    *date          total_water_ul
# +----------+ +------------+ +------------+
# JB366        10-Sep-2020    92
# JB367        10-Sep-2020    128
# JB368        10-Sep-2020    440
# JB369        10-Sep-2020    612
#  (Total: 4)

# %%
DaySummaries & 'date = "11-Sep-2020"'
# Out:
# *mouse_id    *date          total_water_ul
# +----------+ +------------+ +------------+
# JB366        11-Sep-2020    684
# JB367        11-Sep-2020    424
# JB368        11-Sep-2020    820
# JB369        11-Sep-2020    596
#  (Total: 4)
