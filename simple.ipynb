# %%
## package setup and import
import numpy as np
import datajoint as dj
import pandas as pd
import matplotlib.pyplot as plt
import os
import datetime
from pathlib import Path
from scipy.io import loadmat

# %%
## datajoint setup/import for database management
dj.__version__

dj.config['database.host'] = '127.0.0.1'
dj.config['database.port'] = 3306
dj.config['database.user'] = 'root'
dj.config['database.password'] = 'simple'
dj.config['fetch_format'] = 'array'
dj.config['enable_python_native_blobs'] = True 


connection = dj.conn()
connection
# Out:
# Connecting root@127.0.0.1:3306
# DataJoint connection (connected) root@127.0.0.1:3306

# %%
## SETTING UP DATA STORES

datastorefolder = 'D:\Dropbox\BpodInfoseek\Data\''

dj.config['stores'] = {
    'raw_data':{
        'protocol':'file',
        'location': os.path.join(datastorefolder,'raw_data')
    }
}

dj.config.save_global()

# %%
## ESTABLISH SCHEMA

schema = dj.schema('simple')
schema.drop(True)
schema = dj.schema('simple')

# %%
## Manual entry table for mouse identification/attribute labelling
@schema
class Mice(dj.Manual): ## Manual entry table for mouse identification/attribute labelling
    definition = """
    mouse_id : varchar(100) 
    ---
    sex = 'U': enum('F','M','U')
    
    geno = 'C57BL6' : varchar(50)
    """

#     DOB = null : date  # YYYY-MM-DD
#     imaging = null : int

# format for entry of new mouse with new attributes, load later on will create new mouse if not previously entered but will be missing experimental params
mice = Mice()

mice.insert([{'mouse_id' : 'JB366', 'sex' : 'M'},{'mouse_id' : 'JB367','sex' :'F'},{'mouse_id' : 'JB368', 'sex' : 'M'},{'mouse_id' : 'JB369', 'sex' : 'M'}],skip_duplicates=True)
mice

# dj.ERD(schema)
# Out:
# *mouse_id    sex     geno
# +----------+ +-----+ +--------+
# JB366        M       C57BL6
# JB367        F       C57BL6
# JB368        M       C57BL6
# JB369        M       C57BL6
#  (Total: 4)

# %%
mice.proj('sex')
# Out:
# *mouse_id    sex
# +----------+ +-----+
# JB366        M
# JB367        F
# JB368        M
# JB369        M
#  (Total: 4)

# %%
# List all data files in directory using pathlib for insertion in manual table

files = []
datafolder = Path('D:\Dropbox\BpodInfoseek\Data\PythonTest')
# datafolder = Path(r'C:\Users\jbuss\Dropbox\BpodInfoseek\Data\PythonTest')
for file in datafolder.glob('JB*.mat'):
    if file.stat().st_size>3000: # leaves out garbage files!
        thisfile = {}
        thisfile["filename"] = file.name
        thisfile["filepath"] = str(file.parent)
        mouseID,protocol,datestr,timestr = file.stem.split('_')
        thisfile["mouse_id"] = mouseID
        thisfile["protocol"] = protocol
        date_obj = datetime.datetime.strptime(datestr, '%Y%m%d')
        thisfile["sessiondate"] = date_obj.date()
        thisfile["datestr"] = datestr
        time_obj = datetime.datetime.strptime(timestr, '%H%M%S')
#         time_obj = datetime.datetime.strptime(timestr[:len(timestr)-4], '%H%M%S')
        thisfile["sessiontime"] = time_obj.time()
        thisfile["timestr"] = timestr
        files.append(thisfile)

# %%
files
# Out:
# [{'filename': 'JB366_Infoseek_20201013_102926.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(10, 29, 26),
#   'timestr': '102926'},
#  {'filename': 'JB366_Infoseek_20201014_103353.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 14),
#   'datestr': '20201014',
#   'sessiontime': datetime.time(10, 33, 53),
#   'timestr': '103353'},
#  {'filename': 'JB366_Infoseek_20201014_104211.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 14),
#   'datestr': '20201014',
#   'sessiontime': datetime.time(10, 42, 11),
#   'timestr': '104211'},
#  {'filename': 'JB366_Infoseek_20201015_101140.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 15),
#   'datestr': '20201015',
#   'sessiontime': datetime.time(10, 11, 40),
#   'timestr': '101140'},
#  {'filename': 'JB366_Infoseek_20201016_102403.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 16),
#   'datestr': '20201016',
#   'sessiontime': datetime.time(10, 24, 3),
#   'timestr': '102403'},
#  {'filename': 'JB366_Infoseek_20201016_104533.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB366',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 16),
#   'datestr': '20201016',
#   'sessiontime': datetime.time(10, 45, 33),
#   'timestr': '104533'},
#  {'filename': 'JB367_Infoseek_20201013_112258.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB367',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(11, 22, 58),
#   'timestr': '112258'},
#  {'filename': 'JB367_Infoseek_20201014_112858.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB367',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 14),
#   'datestr': '20201014',
#   'sessiontime': datetime.time(11, 28, 58),
#   'timestr': '112858'},
#  {'filename': 'JB367_Infoseek_20201015_105831.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB367',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 15),
#   'datestr': '20201015',
#   'sessiontime': datetime.time(10, 58, 31),
#   'timestr': '105831'},
#  {'filename': 'JB367_Infoseek_20201015_111113.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB367',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 15),
#   'datestr': '20201015',
#   'sessiontime': datetime.time(11, 11, 13),
#   'timestr': '111113'},
#  {'filename': 'JB367_Infoseek_20201016_114857.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB367',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 16),
#   'datestr': '20201016',
#   'sessiontime': datetime.time(11, 48, 57),
#   'timestr': '114857'},
#  {'filename': 'JB368_Infoseek_20201012_162220.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 12),
#   'datestr': '20201012',
#   'sessiontime': datetime.time(16, 22, 20),
#   'timestr': '162220'},
#  {'filename': 'JB368_Infoseek_20201013_130035.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(13, 0, 35),
#   'timestr': '130035'},
#  {'filename': 'JB368_Infoseek_20201013_131145.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(13, 11, 45),
#   'timestr': '131145'},
#  {'filename': 'JB368_Infoseek_20201013_133115.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(13, 31, 15),
#   'timestr': '133115'},
#  {'filename': 'JB368_Infoseek_20201013_135713.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(13, 57, 13),
#   'timestr': '135713'},
#  {'filename': 'JB368_Infoseek_20201014_133626.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 14),
#   'datestr': '20201014',
#   'sessiontime': datetime.time(13, 36, 26),
#   'timestr': '133626'},
#  {'filename': 'JB368_Infoseek_20201015_135045.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 15),
#   'datestr': '20201015',
#   'sessiontime': datetime.time(13, 50, 45),
#   'timestr': '135045'},
#  {'filename': 'JB368_Infoseek_20201016_141452.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB368',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 16),
#   'datestr': '20201016',
#   'sessiontime': datetime.time(14, 14, 52),
#   'timestr': '141452'},
#  {'filename': 'JB369_Infoseek_20201012_155242.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB369',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 12),
#   'datestr': '20201012',
#   'sessiontime': datetime.time(15, 52, 42),
#   'timestr': '155242'},
#  {'filename': 'JB369_Infoseek_20201013_142843.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB369',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 13),
#   'datestr': '20201013',
#   'sessiontime': datetime.time(14, 28, 43),
#   'timestr': '142843'},
#  {'filename': 'JB369_Infoseek_20201014_145931.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB369',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 14),
#   'datestr': '20201014',
#   'sessiontime': datetime.time(14, 59, 31),
#   'timestr': '145931'},
#  {'filename': 'JB369_Infoseek_20201016_155426.mat',
#   'filepath': 'D:\\Dropbox\\BpodInfoseek\\Data\\PythonTest',
#   'mouse_id': 'JB369',
#   'protocol': 'Infoseek',
#   'sessiondate': datetime.date(2020, 10, 16),
#   'datestr': '20201016',
#   'sessiontime': datetime.time(15, 54, 26),
#   'timestr': '155426'}]

# %%
filesDf = pd.DataFrame(files)
# filesDf.groupby(['mouse_id','date']).sum()
# columns = filesDf[["mouse_id","date"]].values
# mousedays = pd.unique(columns)
# print(mousedays)
mousedaysDf = filesDf.groupby(['mouse_id','sessiondate','datestr']).size().reset_index().rename(columns={0:'sessions'})
# mousedaysDf
mousedaysDfshort = mousedaysDf[['mouse_id','sessiondate','datestr']]
mousedaysDfshort
# Out:
#    mouse_id sessiondate   datestr
# 0     JB366  2020-10-13  20201013
# 1     JB366  2020-10-14  20201014
# 2     JB366  2020-10-15  20201015
# 3     JB366  2020-10-16  20201016
# 4     JB367  2020-10-13  20201013
# 5     JB367  2020-10-14  20201014
# 6     JB367  2020-10-15  20201015
# 7     JB367  2020-10-16  20201016
# 8     JB368  2020-10-12  20201012
# 9     JB368  2020-10-13  20201013
# 10    JB368  2020-10-14  20201014
# 11    JB368  2020-10-15  20201015
# 12    JB368  2020-10-16  20201016
# 13    JB369  2020-10-12  20201012
# 14    JB369  2020-10-13  20201013
# 15    JB369  2020-10-14  20201014
# 16    JB369  2020-10-16  20201016

# %%
# MouseDays.drop(True)
@schema
class MouseDays(dj.Manual):
    definition = """
    ->Mice
    datestr : char(8)
    ---
    sessiondate : date
    """
mouseDays = MouseDays()
mouseDays.insert(mousedaysDfshort)
mouseDays
# Out:
# *mouse_id    *datestr     sessiondate
# +----------+ +----------+ +------------+
# JB366        20201013     2020-10-13
# JB366        20201014     2020-10-14
# JB366        20201015     2020-10-15
# JB366        20201016     2020-10-16
# JB367        20201013     2020-10-13
# JB367        20201014     2020-10-14
# JB367        20201015     2020-10-15
# JB367        20201016     2020-10-16
# JB368        20201012     2020-10-12
# JB368        20201013     2020-10-13
# JB368        20201014     2020-10-14
# JB368        20201015     2020-10-15
#    ...
#  (Total: 17)

# %%
# BehaviorSession.drop(True)
@schema
class BehaviorSession(dj.Manual):
    definition = """
    # Infoseek behavior .mat files from a folder
    filename : varchar(127)
    -> MouseDays
    datestr : char(8)
    timestr: char(6)
    protocol : varchar(127)      
    ---
    sessiondate : date
    sessiontime : time
    filepath : varchar(127)
    """
behaviorSession = BehaviorSession()
behaviorSession
# Out:
# *filename    *mouse_id    *datestr    *timestr    *protocol    sessiondate    sessiontime    filepath
# +----------+ +----------+ +---------+ +---------+ +----------+ +------------+ +------------+ +----------+
#
#  (Total: 0)

# %%
behaviorSession.insert(files,skip_duplicates=True)
behaviorSession
# Out:
# *filename      *mouse_id    *datestr     *timestr    *protocol    sessiondate    sessiontime    filepath
# +------------+ +----------+ +----------+ +---------+ +----------+ +------------+ +------------+ +------------+
# JB366_Infoseek JB366        20201013     102926      Infoseek     2020-10-13     10:29:26       D:\Dropbox\Bpo
# JB366_Infoseek JB366        20201014     103353      Infoseek     2020-10-14     10:33:53       D:\Dropbox\Bpo
# JB366_Infoseek JB366        20201014     104211      Infoseek     2020-10-14     10:42:11       D:\Dropbox\Bpo
# JB366_Infoseek JB366        20201015     101140      Infoseek     2020-10-15     10:11:40       D:\Dropbox\Bpo
# JB366_Infoseek JB366        20201016     102403      Infoseek     2020-10-16     10:24:03       D:\Dropbox\Bpo
# JB366_Infoseek JB366        20201016     104533      Infoseek     2020-10-16     10:45:33       D:\Dropbox\Bpo
# JB367_Infoseek JB367        20201013     112258      Infoseek     2020-10-13     11:22:58       D:\Dropbox\Bpo
# JB367_Infoseek JB367        20201014     112858      Infoseek     2020-10-14     11:28:58       D:\Dropbox\Bpo
# JB367_Infoseek JB367        20201015     105831      Infoseek     2020-10-15     10:58:31       D:\Dropbox\Bpo
# JB367_Infoseek JB367        20201015     111113      Infoseek     2020-10-15     11:11:13       D:\Dropbox\Bpo
# JB367_Infoseek JB367        20201016     114857      Infoseek     2020-10-16     11:48:57       D:\Dropbox\Bpo
# JB368_Infoseek JB368        20201012     162220      Infoseek     2020-10-12     16:22:20       D:\Dropbox\Bpo
#    ...
#  (Total: 23)

# %%
len(behaviorSession)
# Out:
# 23

# %%
filename = r'JB366_TestInfoseek_20200916_113754.mat'
filepath = r'D:\Dropbox\BpodInfoseek\Data\PythonTest'
newpath = Path(filepath,filename)
print(newpath)
# Out:
# D:\Dropbox\BpodInfoseek\Data\PythonTest\JB366_TestInfoseek_20200916_113754.mat

# %%
name = 'JB366_TestInfoseek_20200916_113754.mat'
'r'+name
filepath = 'D:\Dropbox\BpodInfoseek\Data\PythonTest'
newpath = Path(filepath,name)
print(newpath)
# Out:
# D:\Dropbox\BpodInfoseek\Data\PythonTest\JB366_TestInfoseek_20200916_113754.mat

# %%
# SessionRawData.drop(True)

# Save raw data

@schema
class SessionRawData(dj.Imported):
    definition = """
    -> BehaviorSession
    ---
    sessiondate = "2020-01-01" : date 
    sessiontime = "000000" : time
    raw_data   : longblob     # raw 'session_data' from Bpod matlab file
    """
    def make(self, key):  # key is the primary key of one of the entries in the table `Scan`
        name = (BehaviorSession & key).fetch1()['filename']
        partpath = (BehaviorSession & key).fetch1()['filepath']
        matdata = loadmat(Path(partpath,name))
        key['raw_data'] = pd.DataFrame(matdata['SessionData'][0])
        key['sessiondate'] = (BehaviorSession & key).fetch1()['sessiondate']
        key['sessiontime'] = (BehaviorSession & key).fetch1()['sessiontime']
#         key['raw_data'] = matdata
        self.insert1(key)

# %%
SessionRawData.populate()
SessionRawData()
# Out:
# *filename      *mouse_id    *datestr     *timestr    *protocol    sessiondate    sessiontime    raw_data
# +------------+ +----------+ +----------+ +---------+ +----------+ +------------+ +------------+ +--------+
# JB366_Infoseek JB366        20201013     102926      Infoseek     2020-10-13     10:29:26       =BLOB=
# JB366_Infoseek JB366        20201014     103353      Infoseek     2020-10-14     10:33:53       =BLOB=
# JB366_Infoseek JB366        20201014     104211      Infoseek     2020-10-14     10:42:11       =BLOB=
# JB366_Infoseek JB366        20201015     101140      Infoseek     2020-10-15     10:11:40       =BLOB=
# JB366_Infoseek JB366        20201016     102403      Infoseek     2020-10-16     10:24:03       =BLOB=
# JB366_Infoseek JB366        20201016     104533      Infoseek     2020-10-16     10:45:33       =BLOB=
# JB367_Infoseek JB367        20201013     112258      Infoseek     2020-10-13     11:22:58       =BLOB=
# JB367_Infoseek JB367        20201014     112858      Infoseek     2020-10-14     11:28:58       =BLOB=
# JB367_Infoseek JB367        20201015     105831      Infoseek     2020-10-15     10:58:31       =BLOB=
# JB367_Infoseek JB367        20201015     111113      Infoseek     2020-10-15     11:11:13       =BLOB=
# JB367_Infoseek JB367        20201016     114857      Infoseek     2020-10-16     11:48:57       =BLOB=
# JB368_Infoseek JB368        20201012     162220      Infoseek     2020-10-12     16:22:20       =BLOB=
#    ...
#  (Total: 23)

# %%
# ex = SessionRawData & 'filename = "JB368_Infoseek_20201012_162220.mat"'
name = 'JB368_Infoseek_20201012_162220.mat'
filepath = 'D:\Dropbox\BpodInfoseek\Data\PythonTest'
newpath = Path(filepath,name)
ex = loadmat(newpath)
# sorted(ex.keys())
sessiondata = ex['SessionData']
sessiondata.dtype
# data = ex.fetch()['raw_data']
# # data = pd.DataFrame(data)
# data
namelist = sessiondata.dtype.names
for n in sessiondata.dtype.names:
    print(n)
# Out:
# TrialCounts
# PlotOutcomes
# TrialTypes
# Outcomes
# OrigTrialTypes
# OrigRewardTypes
# EventNames
# Info
# nTrials
# RawEvents
# RawData
# TrialStartTimestamp
# TrialEndTimestamp
# SettingsFile
# TrialSettings
# Notes
# MarkerCodes

# %%
sessiondata = SessionRawData & 'filename = "JB368_Infoseek_20201012_162220.mat"'
data = sessiondata.fetch()['raw_data']

# %%
@schema
class Calc(dj.Computed):
    definition = """
    -> SessionRawData
    ---
    """
    def make(self, key):  # key is the primary key of one of the entries in the table `Scan`
        data = (SessionRawData & key).fetch1()['raw_data']
        key['new_data'] = data
#         key['raw_data'] = matdata
        self.insert1(key)

Calc().populate
Calc
# Out:
# __main__.Calc

# %%
@schema
class SessionProcessed(dj.Computed):
    definition = """
    -> SessionRawData
    ---
    outcomes : longblob
    """
    
    def make(self, key):
        data = ((SessionRawData & key).fetch1()['raw_data'])
        outcomes = pd.DataFrame(data['Outcomes'][0][0])
        key['outcomes'] = outcomes
        
        self.insert1(key)
        
        print("test")
SessionProcessed.drop(True)
# Out:
# Tables dropped.  Restart kernel.

# %%
SessionProcessed().populate
SessionProcessed
# Out:
# __main__.SessionProcessed

# %%
@schema
class SessionData(dj.Computed):
    definition = """
    -> SessionRawData
    ---
    SessionSettings : blob
    nTrials : longblog
    Outcomes : longblog
    StartTimes : longblog
    EndTimes : longblog
    States : longblog
    Events : longblog
    """
    
    def make(self, key):  # key is the primary key of one of the entries in the table `Scan`
